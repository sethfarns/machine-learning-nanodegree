# %% [markdown]
# Definition: The problem of pre-processing a set of features to create a new (smaller? more compact?) feature set, while retaining as much (relevant? useful?) information as possible
#
# Linear combination of original features
#
# ### Why do feature transformation?
#
# ad hoc information retrieval problem
#
# want to retrieve the subset of documents that is exactly relevant to the query; query is ad hoc, i.e. you don't know what it's going to be beforehand, so you don't necessarily know how to structure your data to optimize the document retrieval
#
# what are our features?
#
# * words
#
# problems with words:
# * lots of them
# * multiple meanings for some words (polysemy)
# * many words mean the same things (synonomy)
#
# feature selection cannot solve these problems
#
# ### Independent Components Analysis (ICA)
#
# * PCA is about finding correlation, by maximizing variance, allowing you to do reconstruction
# * ICA is about independence, reducing feature set to those features that are statistically independent of one another
#
# Blind source separation problem/Cocktail party problem
# * Difficulty of separating out one conversation from all the other conversations going on at the same time
# * Or, imagine that we have different, unseen speakers, all talking at the same time, and multiple microphones at different locations that are picking up all the noise--how do we separate out an individual speaker?
# * ICA was designed for exactly this model
#
# ### PCA vs. ICA
#
# * Maximize variance: PCA
# * Maximize mutual information: ICA
# * Mutually orthogonal: PCA
# * Mutually independent: ICA
# * Ordered features: ICA
# * Non-ordered/bag of features: PCA
#
# ### Applications
#
# * Blind source separation: ICA
# * Directional: ICA
# * Faces (eigen faces)
#     * PCA finds the average face
#     * ICA finds individual features (noses, eyes, hair, etc.)
# * Natural scenes
#     * ICA finds edges
# * Documents
#     * ICA gives you topics
#
# ### Randomized Components Analysis
#
# * RCA = Randomized Components Analysis
#     * generates random directions
#     * works really well for dimensionality reduction prior to classification
#     * tends not to project to as few dimensions as PCA
#     * fast!
#
# ### Linear Discriminant Analysis (LDA)
#
# * finds a projection that discriminates based on the label
